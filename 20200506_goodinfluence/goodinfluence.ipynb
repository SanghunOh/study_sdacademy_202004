# %%
import pandas as pd

# %%
dump_excel = pd.read_excel('./goodinfluence.xlsx', header=1)

# %%
import sqlite3 
conn = sqlite3.connect('./20200506-GoodInfluence_YoonHyein.db')

# %%
dump_excel.to_sql('temp_dump_excel_table', conn, if_exists='replace', index=False)

# %%
dump_excel
# Out:
#       순번  지역   진함              상호명  \
# 0      1  강원  진진희           진로1973
# 1      2  강원  주진희             카페터틀
# 2      3  강원  진말진            황금발진당
# 3      4  강원  추순자            골진닭갈비
# 4      5  강원  진정화           화요일케이크
# ..   ...  ..  ...              ...
# 527  528  충북  박나나            나나에이드
# 528  529  충북  박진용  응급실국물떡볶이(청주복대점)
# 529  530  충북  진동호             카페드림
# 530  531  충북  정상진       피자쏘렌토(오송점)
# 531  532  충북  진남훈       짬뽕지존 충주시청점
#
#                                            사업장 연락처  \
# 0                                       5882649286
# 1                                     588 521 8295
# 2                                   588  784 82251
# 3                                       5885817911
# 4    화요일케이크\n (51545946577)\n 카페레브\n (57541272855)
# ..                                             ...
# 527                                     7546482886
# 528                                   548 284 1191
# 529                                   548 288 2126
# ...
